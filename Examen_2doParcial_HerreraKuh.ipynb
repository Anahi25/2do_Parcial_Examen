# %% [markdown]
# # Importamos la libreria de panda

# %%
import pandas as pd

# %% [markdown]
# # Importamos nuestro archivo csv que subimos desde S3

# %%
df = df = pd.read_csv("https://testutmvanessa.s3.amazonaws.com/data.csv")

# %%
df
# Out:
#    acousticness                            artists  danceability  duration_ms  \
# 1      0.643000          ["Screamin' Jay Hawkins"]         0.852       150200
# 8      0.996000               ['Francisco Canaro']         0.469       146840
# 5      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.424       198627
# 7      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.474       186173
# 0      0.991000                    ['Mamie Smith']         0.598       168333
# 2      0.993000                    ['Mamie Smith']         0.647       163827
# 6      0.992000                    ['Mamie Smith']         0.782       195200
# 9      0.006820                         ['Meetya']         0.571       476304
# 4      0.295000                           ['Mixe']         0.704       165224
# 3      0.000173                ['Oscar Velazquez']         0.730       422087
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# ...

# %% [markdown]
# # Accedemos a ver las columnas que tenemos

# %%
df.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %% [markdown]
# # Mostramos los primeros 10 artistas

# %%
df = df.head(10).sort_values(by='artists')

# %%
df
# Out:
#    acousticness                            artists  danceability  duration_ms  \
# 1      0.643000          ["Screamin' Jay Hawkins"]         0.852       150200
# 8      0.996000               ['Francisco Canaro']         0.469       146840
# 5      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.424       198627
# 7      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.474       186173
# 0      0.991000                    ['Mamie Smith']         0.598       168333
# 2      0.993000                    ['Mamie Smith']         0.647       163827
# 6      0.992000                    ['Mamie Smith']         0.782       195200
# 9      0.006820                         ['Meetya']         0.571       476304
# 4      0.295000                           ['Mixe']         0.704       165224
# 3      0.000173                ['Oscar Velazquez']         0.730       422087
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# ...

# %% [markdown]
# # Importamos nuevas librerias

# %%
# Numpy operaciones de matrices 
import numpy as np 
# seaborn es para graficar y hacer comparativos
import seaborn as sns 
 
# Graficas de forma general 
#import matplotlib as plt 
from matplotlib import pyplot as plt 
# %matplotlib inline

# %% [markdown]
# # Ahora los ordenamos alfabeticamente

# %%
artist = df.sort_values('artists', ascending=True)
artist.head(10)
# Out:
#    acousticness                            artists  danceability  duration_ms  \
# 1      0.643000          ["Screamin' Jay Hawkins"]         0.852       150200
# 8      0.996000               ['Francisco Canaro']         0.469       146840
# 5      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.424       198627
# 7      0.996000  ['Mamie Smith & Her Jazz Hounds']         0.474       186173
# 0      0.991000                    ['Mamie Smith']         0.598       168333
# 2      0.993000                    ['Mamie Smith']         0.647       163827
# 6      0.992000                    ['Mamie Smith']         0.782       195200
# 9      0.006820                         ['Meetya']         0.571       476304
# 4      0.295000                           ['Mixe']         0.704       165224
# 3      0.000173                ['Oscar Velazquez']         0.730       422087
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# ...

# %%
artist['artists']
# Out:
# 1            ["Screamin' Jay Hawkins"]
# 8                 ['Francisco Canaro']
# 5    ['Mamie Smith & Her Jazz Hounds']
# 7    ['Mamie Smith & Her Jazz Hounds']
# 0                      ['Mamie Smith']
# 2                      ['Mamie Smith']
# 6                      ['Mamie Smith']
# 9                           ['Meetya']
# 4                             ['Mixe']
# 3                  ['Oscar Velazquez']
# Name: artists, dtype: object

# %% [markdown]
# # Observamos los datos correlativos

# %%
df.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.337654    -0.803932 -0.965413 -0.324354
# danceability         -0.337654      1.000000     0.027898  0.287321  0.193304
# duration_ms          -0.803932      0.027898     1.000000  0.677056 -0.183365
# energy               -0.965413      0.287321     0.677056  1.000000  0.402589
# explicit             -0.324354      0.193304    -0.183365  0.402589  1.000000
# instrumentalness     -0.335804     -0.532172     0.571833  0.317639 -0.297252
# key                  -0.110494     -0.313172    -0.070517  0.178840  0.482902
# liveness              0.325035     -0.066690    -0.447913 -0.291553  0.394807
# loudness             -0.729360      0.464020     0.467829  0.747577  0.404315
# mode                  0.077072     -0.447004     0.383169 -0.219547 -0.509175
# popularity           -0.172517      0.307009     0.207237  0.166455 -0.221163
# ...

# %% [markdown]
# # Accedemos a sacar los datos estadisticos

# %%
df.describe()
# Out:
#        acousticness  danceability   duration_ms     energy   explicit  \
# count     10.000000     10.000000      10.00000  10.000000  10.000000
# mean       0.690899      0.625100  227281.50000   0.396430   0.100000
# std        0.428867      0.143415  118914.78051   0.271053   0.316228
# min        0.000173      0.424000  146840.00000   0.057300   0.000000
# 25%        0.382000      0.498250  164176.25000   0.227500   0.000000
# 50%        0.991500      0.622500  177253.00000   0.242000   0.000000
# 75%        0.995250      0.723500  197770.25000   0.659500   0.000000
# max        0.996000      0.852000  476304.00000   0.798000   1.000000
#
#        instrumentalness       key   liveness   loudness       mode  \
# count         10.000000  10.00000  10.000000  10.000000  10.000000
# mean           0.364619   5.70000   0.235590 -10.462900   0.700000
# std            0.430704   3.12872   0.148099   3.847131   0.483046
# ...

# %% [markdown]
# # Sacamos el valor maximo

# %%
df.max()
# Out:
# acousticness                         0.996
# artists                ['Oscar Velazquez']
# danceability                         0.852
# duration_ms                         476304
# energy                               0.798
# explicit                                 1
# id                  5DlCyqLyX2AOVDTjjkDZ8x
# instrumentalness                      0.96
# key                                     10
# liveness                             0.519
# loudness                            -6.036
# mode                                     1
# name                             Xuniverxe
# popularity                              17
# release_date                    1920-10-01
# speechiness                          0.174
# tempo                              149.976
# valence                               0.95
# year                                  1920
# dtype: object

# %% [markdown]
# # Sacamos el valor minimo

# %%
df.min()
# Out:
# acousticness                         0.000173
# artists             ["Screamin' Jay Hawkins"]
# danceability                            0.424
# duration_ms                            146840
# energy                                 0.0573
# explicit                                    0
# id                     02FzJbHtqElixxCmrpSCUa
# instrumentalness                     1.61e-06
# key                                         0
# liveness                               0.0809
# loudness                              -18.717
# mode                                        0
# name                           Arkansas Blues
# popularity                                  0
# release_date                             1920
# speechiness                            0.0289
# tempo                                  78.784
# valence                                0.0422
# year                                     1920
# dtype: object

# %% [markdown]
# # Sacamos el promedio

# %%
df.mean()
# Out:
# acousticness             0.690899
# danceability             0.625100
# duration_ms         227281.500000
# energy                   0.396430
# explicit                 0.100000
# instrumentalness         0.364619
# key                      5.700000
# liveness                 0.235590
# loudness               -10.462900
# mode                     0.700000
# popularity               5.600000
# speechiness              0.068680
# tempo                  110.989700
# valence                  0.468420
# year                  1920.000000
# dtype: float64

# %% [markdown]
# # Sacamos la mediana

# %%
df.median()
# Out:
# acousticness             0.9915
# danceability             0.6225
# duration_ms         177253.0000
# energy                   0.2420
# explicit                 0.0000
# instrumentalness         0.1062
# key                      5.0000
# liveness                 0.1855
# loudness               -10.5910
# mode                     1.0000
# popularity               4.5000
# speechiness              0.0563
# tempo                  112.9730
# valence                  0.4820
# year                  1920.0000
# dtype: float64

# %% [markdown]
# # Sacamos la varianza

# %%
df.var()
# Out:
# acousticness        1.839271e-01
# danceability        2.056788e-02
# duration_ms         1.414073e+10
# energy              7.346987e-02
# explicit            1.000000e-01
# instrumentalness    1.855062e-01
# key                 9.788889e+00
# liveness            2.193326e-02
# loudness            1.480042e+01
# mode                2.333333e-01
# popularity          3.271111e+01
# speechiness         1.757722e-03
# tempo               5.602102e+02
# valence             7.496021e-02
# year                0.000000e+00
# dtype: float64

# %% [markdown]
# # Mostramos algunas columnas que se pueden relacionar

# %%
relation = df[['artists','danceability','duration_ms','energy']]

# %%
relation.head(10)
# Out:
#                              artists  danceability  duration_ms  energy
# 1          ["Screamin' Jay Hawkins"]         0.852       150200  0.5170
# 8               ['Francisco Canaro']         0.469       146840  0.2380
# 5  ['Mamie Smith & Her Jazz Hounds']         0.424       198627  0.2450
# 7  ['Mamie Smith & Her Jazz Hounds']         0.474       186173  0.2390
# 0                    ['Mamie Smith']         0.598       168333  0.2240
# 2                    ['Mamie Smith']         0.647       163827  0.1860
# 6                    ['Mamie Smith']         0.782       195200  0.0573
# 9                         ['Meetya']         0.571       476304  0.7530
# 4                           ['Mixe']         0.704       165224  0.7070
# 3                ['Oscar Velazquez']         0.730       422087  0.7980

# %%
relation = df[['danceability','duration_ms','energy']]

# %%
relation.head(10)
# Out:
#    danceability  duration_ms  energy
# 1         0.852       150200  0.5170
# 8         0.469       146840  0.2380
# 5         0.424       198627  0.2450
# 7         0.474       186173  0.2390
# 0         0.598       168333  0.2240
# 2         0.647       163827  0.1860
# 6         0.782       195200  0.0573
# 9         0.571       476304  0.7530
# 4         0.704       165224  0.7070
# 3         0.730       422087  0.7980

# %%
relation = df[['artists','instrumentalness']]

# %%
relation.head(10)
# Out:
#    danceability  duration_ms  energy
# 1         0.852       150200  0.5170
# 8         0.469       146840  0.2380
# 5         0.424       198627  0.2450
# 7         0.474       186173  0.2390
# 0         0.598       168333  0.2240
# 2         0.647       163827  0.1860
# 6         0.782       195200  0.0573
# 9         0.571       476304  0.7530
# 4         0.704       165224  0.7070
# 3         0.730       422087  0.7980

# %%
relation = df[['artists','popularity']]
relation.head(10)
# Out:
#                              artists  popularity
# 1          ["Screamin' Jay Hawkins"]           7
# 8               ['Francisco Canaro']           0
# 5  ['Mamie Smith & Her Jazz Hounds']           9
# 7  ['Mamie Smith & Her Jazz Hounds']           0
# 0                    ['Mamie Smith']          12
# 2                    ['Mamie Smith']           4
# 6                    ['Mamie Smith']           5
# 9                         ['Meetya']           0
# 4                           ['Mixe']           2
# 3                ['Oscar Velazquez']          17

# %% [markdown]
# # ¿Cuales valores pueden tener una relacion lineal positiva, demuestre y diga porqué lo considera asi?

# %% [markdown]
# # R= La relacion se puede hacer entre el artista, la danceabilidad, la duracion y la energia esto permite ver la capacidad de cada artista para analizar su desempeño

# %% [markdown]
# # R= Tambien se puede relacionar la danceabilidad, la duracion, la energia por si solas para poder hacer una grafica de su condicion fisica de cada artista

# %% [markdown]
# # Ejemplo de la relacion lineal positiva

# %%
sns.pairplot(relation, kind ='reg')
plt.show()

# %% [markdown]
# # Hacemos una relacion mas detallada de los primeros 6 datos

# %%
portiondata = relation.head(6)
sns.pairplot(portiondata, kind ='reg')
plt.show()

# %% [markdown]
# # Accedemos a explorar unicamente la energia

# %%
sns.distplot(df.energy)

# %% [markdown]
# # Accedemos a explorar la danceabilidad

# %%
sns.distplot(df.danceability)

# %% [markdown]
# # Accedemos a explorar la duracion

# %%
sns.distplot(df.duration_ms)
